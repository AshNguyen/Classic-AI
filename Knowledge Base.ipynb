M, Saturday Closed,  Sunday Closed,') :- price('$'), distance(close), cuisine_type(italian).
 restaurant('Tanta', 'Esmeralda 938, C1072 C1007ABL, Buenos Aires', 'Monday 12PM~12AM, Tuesday 12PM~12AM, Wednesday 12PM~12AM, Thursdday 12PM~12AM, Friday 12PM~12AM, Saturday 12PM~12AM,  Sunday Closed,') :- price('$$'), distance(close), cuisine_type(peruvian).
 restaurant('La Mar', 'Arévalo 2024, C1414 CABA', 'Monday 8PM~12AM, Tuesday 12_30~4PM, 7PM~12AM, Wednesday 8PM~12AM, Thursdday 12_30~4PM, 7PM~12AM, Friday 12_30~4PM, 7PM~12AM, Saturday 12_30~4PM, 7PM~12AM,  Sunday 12_30~4PM, 7PM~12AM,') :- price('$$$'), distance(far), cuisine_type(peruvian).


price(X) :- ask_list(price, X, '[$, $$, $$$]'). 
distance(X) :- ask_list(distance, X, '[close, medium, far]'). 
cuisine_type(X) :- ask_list(cuisine_type, X, '[asian, argentinian, cafe, contemporary, icecream, peruvian, italian]').

% The code below implements the prompting to ask the user:

ask_list(A, V, List):-
known(yes, A, V), 
# !.

ask_list(A, V, List):-
known(yes, A, _),
!, fail.

ask_list(A, V, List):-
display_list_py(A, List), 
read_list_choice_py(A, V, Y),
asserta(known(yes, A, Y)), 
Y = V.
"""

with open("KB.pl", "w") as text_file:
    text_file.write(KB)

# %%
from pyswip.prolog import Prolog
from pyswip.easy import *
prolog = Prolog() # Global handle to interpreter

retractall = Functor("retractall")
known = Functor("known",3)

def display_list_py(A, l): 
    sys.stdout.flush()
    print('Choose one value of {} from given list: '.format(str(A)) + str(l))
    return True

def read_list_choice_py(A, V, Y): 
    Y.unify(raw_input("Choice for " + str(A) + " is:"))
    return True


display_list_py.arity = 2
read_list_choice_py.arity = 3

registerForeign(display_list_py)
registerForeign(read_list_choice_py)


prolog.consult("KB.pl") # open the KB
call(retractall(known))

results = []
for result in prolog.query("restaurant(X, Y, Z).", maxresult=30):
    results.append([result['X'], result['Y'], result['Z']])
    
    
print(results)
    
# if not results: 
#     print('No restaurant match your query. Please try an another query.')
# else: 
#     for item in results:
#         item[2] = item[2].replace('_', ':')
#         print('You can go to ' + item[0] + ', which is at ' + item[1] + '. It open times are ' + item[2])

# %%
#parsing
import pandas as pd 
import numpy as np

data = pd.read_csv('/Users/ash/Downloads/restaurant_data.csv')

# %%
def parse_one_restaurant(row): 
    base_string_1 = "restaurant({}, {}, '_opentime_) :- price('{}'), distance({}), cuisine_type({}).".format(
                   "'"+str(row['Name'])+"'", "'"+str(row['Address'])+"'",\
                   str(row['Price']).lower(), str(row['Distance']).lower(), str(row['Type of Cuisine']).lower()) 
    for day in ['Monday', 'Tuesday', 'Wednesday', 'Thursdday', 'Friday', 'Saturday', 'Sunday']: 
        time = (day + ' ' + str(row[day]) + ',').replace(':', '_')
        time = time.replace('–', '~')
        if day == 'Sunday':
            base_string_1 = base_string_1.replace('_opentime_', ' ' + time + "'")
            break
        index = base_string_1.find('_opentime_')
        base_string_1 = base_string_1[:index] + time + ' ' + base_string_1[index:]
    return base_string_1

def parse_data(restaurant_data): 
    result = ""
    for _ in range(restaurant_data.shape[0]):
        result = result + " " + parse_one_restaurant(restaurant_data.iloc[_]) + "\n"
    return result

# %%
def parse_result(result):
    parsed = {}
    for item in result: 
        parsed[item[0]] = {}
        parsed[item[0]]['address'] = item[1]
        parsed[item[0]]['open_time'] = item[2]
    return parsed

print(parse_result(results))
# Out:
# {'Taragui': {'address': 'Marcelo Torcuato de Alvear 997, C1058AAM CABA', 'open_time': 'Monday 11AM~10PM, Tuesday 11AM~10PM, Wednesday 11AM~10PM, Thursdday 11AM~10PM, Friday 11AM~10PM, Saturday 11AM~10PM,  Sunday Closed,'}, 'Ditali': {'address': 'Maipú 902, C1006ACN CABA', 'open_time': 'Monday 7AM~1AM, Tuesday 7AM~1AM, Wednesday 7AM~1AM, Thursdday 7AM~1AM, Friday 7AM~2AM, Saturday 7AM~2AM,  Sunday 8AM~1AM,'}}

# %%
# GUI INTERFACE

KB = """
% Enter your KB below this line:

 restaurant('Taragui', 'Marcelo Torcuato de Alvear 997, C1058AAM CABA', 'Monday 11AM~10PM, Tuesday 11AM~10PM, Wednesday 11AM~10PM, Thursdday 11AM~10PM, Friday 11AM~10PM, Saturday 11AM~10PM,  Sunday Closed,') :- price('$'), distance(close), cuisine_type(argentinian).
 restaurant('Santos Manjares', 'Paraguay 938, C1057AAN CABA', 'Monday 11_45AM~12AM, Tuesday 11_45AM~12AM, Wednesday 11_45AM~12AM, Thursdday 11_45AM~12AM, Friday 11_45AM~12AM, Saturday 11_45AM~12AM,  Sunday Closed,') :- price('$$'), distance(close), cuisine_type(argentinian).
 restaurant('Ditali', 'Maipú 902, C1006ACN CABA', 'Monday 7AM~1AM, Tuesday 7AM~1AM, Wednesday 7AM~1AM, Thursdday 7AM~1AM, Friday 7AM~2AM, Saturday 7AM~2AM,  Sunday 8AM~1AM,') :- price('$'), distance(close), cuisine_type(argentinian).
 restaurant('Elena', 'C, Posadas 1086, C1011 ABB, Buenos Aires', 'Monday 7AM~12_30AM, Tuesday 7AM~12_30AM, Wednesday 7AM~12_30AM, Thursdday 7AM~12_30AM, Friday 7AM~12_30AM, Saturday 7AM~12_30AM,  Sunday 7AM~12_30AM,') :- price('$$$'), distance(medium), cuisine_type(argentinian).
 restaurant('Las Cabras', 'Fitz Roy 1795, C1414 CABA', 'Monday 12PM~1AM, Tuesday 12PM~1AM, Wednesday 12PM~1AM, Thursdday 12PM~1AM, Friday 12PM~1AM, Saturday 12PM~1AM,  Sunday 12PM~1AM,') :- price('$$'), distance(far), cuisine_type(argentinian).
 restaurant('Chori', 'Thames 1653, C1414DDG CABA', 'Monday 12_30PM~12_30AM, Tuesday 12_30PM~12_30AM, Wednesday 12_30PM~12_30AM, Thursdday 12_30PM~12_30AM, Friday 12_30PM~1AM, Saturday 12_30PM~1AM,  Sunday 12_30PM~12_30AM,') :- price('$'), distance(far), cuisine_type(argentinian).
 restaurant('Pizzeria Guerrin', 'Av. Corrientes 1368, C1043 CABA', 'Monday 11AM~1AM, Tuesday 11AM~1AM, Wednesday 11AM~1AM, Thursdday 11AM~1AM, Friday 11AM~2AM, Saturday 11AM~2AM,  Sunday 11AM~1AM,') :- price('$'), distance(medium), cuisine_type(argentinian).
 restaurant('Piola', 'Libertad 1078, C1012AAU CABA', 'Monday 12~4PM, 6PM~1AM, Tuesday 12~4PM, 6PM~1AM, Wednesday 12~4PM, 6PM~1AM, Thursdday 12~4PM, 6PM~2AM, Friday 12~4PM, 6PM~2AM, Saturday 7PM~1AM,  Sunday 7PM~1AM,') :- price('$$'), distance(medium), cuisine_type(italian).
 restaurant('Core Italian', 'Maipú 819, C1006ACK CABA', 'Monday 9AM~7PM, Tuesday 9AM~7PM, Wednesday 9AM~7PM, Thursdday 9AM~7PM, Friday 9AM~7PM, Saturday Closed,  Sunday Closed,') :- price('$'), distance(close), cuisine_type(italian).
 restaurant('Tanta', 'Esmeralda 938, C1072 C1007ABL, Buenos Aires', 'Monday 12PM~12AM, Tuesday 12PM~12AM, Wednesday 12PM~12AM, Thursdday 12PM~12AM, Friday 12PM~12AM, Saturday 12PM~12AM,  Sunday Closed,') :- price('$$'), distance(close), cuisine_type(peruvian).
 restaurant('La Mar', 'Arévalo 2024, C1414 CABA', 'Monday 8PM~12AM, Tuesday 12_30~4PM, 7PM~12AM, Wednesday 8PM~12AM, Thursdday 12_30~4PM, 7PM~12AM, Friday 12_30~4PM, 7PM~12AM, Saturday 12_30~4PM, 7PM~12AM,  Sunday 12_30~4PM, 7PM~12AM,') :- price('$$$'), distance(far), cuisine_type(peruvian).


price(X) :- ask_list(price, X, '[$, $$, $$$]'). 
distance(X) :- ask_list(distance, X, '[close, medium, far]'). 
cuisine_type(X) :- ask_list(cuisine_type, X, '[asian, argentinian, cafe, contemporary, icecream, peruvian, italian]').

% The code below implements the prompting to ask the user:

ask_list(A, V, List):-
known(yes, A, V), 
# !.

ask_list(A, V, List):-
known(yes, A, _),
!, fail.

ask_list(A, V, List):-
read_list_choice_py(A, V, Y),
asserta(known(yes, A, Y)), 
Y = V.
"""

with open("KB.pl", "w") as text_file:
    text_file.write(KB)

# %%
from pyswip.prolog import Prolog
from pyswip.easy import *
prolog = Prolog() # Global handle to interpreter

def query_the_KB(query): 
    cuisine_type, price, distance = query
    retractall = Functor("retractall")
    known = Functor("known",3)
    
    def read_list_choice_py(A, V, Y): 
        if str(A) == 'price':
            Y.unify(price.lower())
            return True
        elif str(A) == 'distance':
            Y.unify(distance.lower())
            return True
        elif str(A) == 'cuisine_type':
            Y.unify(cuisine_type.lower())
            return True

    read_list_choice_py.arity = 3
    registerForeign(read_list_choice_py)


    prolog.consult("KB.pl") # open the KB
    call(retractall(known))

    results = []
    for result in prolog.query("restaurant(X, Y, Z).", maxresult=30):
        results.append([result['X'], result['Y'], result['Z']])
    return results

def parse_result(result):
    parsed = {}
    for item in result: 
        parsed[item[0]] = {}
        parsed[item[0]]['address'] = item[1]
        parsed[item[0]]['open_time'] = item[2]
    return parsed

def GUI_interface(queries): 
    results = dict()
    for query in queries: 
        results.update(query_the_KB(query))
    return results
